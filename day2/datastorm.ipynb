# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### load the dataset

# %%
df=pd.read_csv("credit_card_default_train.csv")
test=pd.read_csv("credit_card_default_test.csv")
test1=pd.read_csv("credit_card_default_test.csv")

# %%
df.head()
# Out:
#   Client_ID Balance_Limit_V1 Gender EDUCATION_STATUS MARITAL_STATUS  \
# 0        A2               1M      M         Graduate          Other
# 1        A3               1M      F      High School          Other
# 2        A4             100K      F      High School         Single
# 3        A5             200K      F         Graduate         Single
# 4        A6               1M      F         Graduate          Other
#
#             AGE  PAY_JULY  PAY_AUG  PAY_SEP  PAY_OCT  ...  DUE_AMT_OCT  \
# 0         31-45        -1       -1       -1       -1  ...        39418
# 1  Less than 30         0       -1       -1       -1  ...        43530
# 2         31-45         4        3        2        2  ...            0
# 3         31-45         2        0        0        0  ...        97309
# 4         31-45         2        2        0        0  ...       435354
#
#    DUE_AMT_NOV  DUE_AMT_DEC  PAID_AMT_JULY  PAID_AMT_AUG  PAID_AMT_SEP  \
# 0       162772       -13982           3437          6004         39418
# 1        80811       124590         151818         46200         43530
# 2            0            0              0             0             0
# 3       100353       102740           3855          3890          3696
# 4       445271       453899              0         20790         16170
#
#    PAID_AMT_OCT  PAID_AMT_NOV  PAID_AMT_DEC  NEXT_MONTH_DEFAULT
# 0        162772             0        538165                   0
# 1         80811           942         33666                   0
# 2             0             0             0                   1
# 3          4620          4049          3918                   1
# 4         17325         16401         17325                   0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### drop the Client_ID column and select categorical data

# %%
df=df.drop('Client_ID',axis=1)
client_id=test['Client_ID']
test=test.drop('Client_ID',axis=1)

labeldata=df.select_dtypes(include=[object,bool])
labeldata_test=test.select_dtypes(include=[object,bool])

# %% [markdown]
# ### preproccesing data (label encode the cetogorical features)

# %%
from sklearn import preprocessing

# %%
labelEncoder=preprocessing.LabelEncoder()
X_2=labeldata.apply(labelEncoder.fit_transform)
X_2_test=labeldata_test.apply(labelEncoder.fit_transform)

X_2.head()
# Out:
#    Balance_Limit_V1  Gender  EDUCATION_STATUS  MARITAL_STATUS  AGE
# 0                 3       1                 0               0    0
# 1                 3       0                 1               0    2
# 2                 2       0                 1               1    0
# 3                 5       0                 0               1    0
# 4                 3       0                 0               0    0

# %% [markdown]
# ### append new encoded features to the dataFrame

# %%
df['Balance_Limit_V1']=X_2.Balance_Limit_V1
df['Gender']=X_2.Gender
df['EDUCATION_STATUS']=X_2.EDUCATION_STATUS
df['MARITAL_STATUS']=X_2.MARITAL_STATUS
df['AGE']=X_2.AGE

# %% [markdown]
# # Feature Engineering
#
# ### using correlation matrix .

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col1 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col2 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col3 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col4 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col5 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col6 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col7 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col8 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col9 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col10 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col11 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col12 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col13 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col14 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col15 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col16 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col17 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col18 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col19 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col20 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col21 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col22 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row0_col23 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col0 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col2 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col3 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col4 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col5 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col6 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col7 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col8 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col9 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col10 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col11 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col12 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col13 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col14 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col15 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col16 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col17 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col18 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col19 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col20 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col21 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col22 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row1_col23 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row2_col0 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row2_col1 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row2_col3 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row2_col4 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row2_col5 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row2_col6 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row2_col7 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row2_col8 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row2_col9 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row2_col10 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_77bc2e26_5009_11ea_96c5_3d02d66d1cb9row2_col11 {
#             background-color:  #5470de;

# %%
df['DUE_AMT']=(df['DUE_AMT_JULY']+df['DUE_AMT_AUG']+df['DUE_AMT_SEP']+df['DUE_AMT_OCT']+
       df['DUE_AMT_NOV']+ df['DUE_AMT_DEC'])/6

df['PAY']=(df['PAY_JULY']+df['PAY_AUG']+df['PAY_SEP']+df['PAY_OCT']+
       df['PAY_NOV']+ df['PAY_DEC'])/6
# df=df.drop(['DUE_AMT_JULY', 'DUE_AMT_AUG', 'DUE_AMT_SEP', 'DUE_AMT_OCT',
#        'DUE_AMT_NOV', 'DUE_AMT_DEC'],axis=1)

test['DUE_AMT']=(test['DUE_AMT_JULY']+test['DUE_AMT_AUG']+test['DUE_AMT_SEP']+test['DUE_AMT_OCT']+
       test['DUE_AMT_NOV']+ test['DUE_AMT_DEC'])/6
test['PAY']=(test['PAY_JULY']+test['PAY_AUG']+test['PAY_SEP']+test['PAY_OCT']+
       test['PAY_NOV']+ test['PAY_DEC'])/6

# test=test.drop(['DUE_AMT_JULY', 'DUE_AMT_AUG', 'DUE_AMT_SEP', 'DUE_AMT_OCT',
#        'DUE_AMT_NOV', 'DUE_AMT_DEC'],axis=1)

# %%
test['Balance_Limit_V1']=X_2_test.Balance_Limit_V1
test['Gender']=X_2_test.Gender
test['EDUCATION_STATUS']=X_2_test.EDUCATION_STATUS
test['MARITAL_STATUS']=X_2_test.MARITAL_STATUS
test['AGE']=X_2_test.AGE

# %%
df.head()
# Out:
#    Balance_Limit_V1  Gender  EDUCATION_STATUS  MARITAL_STATUS  AGE  PAY_JULY  \
# 0                 3       1                 0               0    0        -1
# 1                 3       0                 1               0    2         0
# 2                 2       0                 1               1    0         4
# 3                 5       0                 0               1    0         2
# 4                 3       0                 0               0    0         2
#
#    PAY_AUG  PAY_SEP  PAY_OCT  PAY_NOV  ...  DUE_AMT_DEC  PAID_AMT_JULY  \
# 0       -1       -1       -1       -1  ...       -13982           3437
# 1       -1       -1       -1       -1  ...       124590         151818
# 2        3        2        2       -2  ...            0              0
# 3        0        0        0        0  ...       102740           3855
# 4        2        0        0        0  ...       453899              0
#
#    PAID_AMT_AUG  PAID_AMT_SEP  PAID_AMT_OCT  PAID_AMT_NOV  PAID_AMT_DEC  \
# 0          6004         39418        162772             0        538165
# 1         46200         43530         80811           942         33666
# 2             0             0             0             0             0
# 3          3890          3696          4620          4049          3918
# 4         20790         16170         17325         16401         17325
#
#    NEXT_MONTH_DEFAULT        DUE_AMT       PAY
# 0                   0   33474.833333 -1.000000
# 1                   0  130174.666667 -0.666667
# 2                   1    8040.000000  1.166667
# 3                   1   96483.333333  0.333333
# 4                   0  435555.166667  0.666667
#
# [5 rows x 26 columns]

# %% [markdown]
# ### separate the dataframe to features and target

# %%
Y=df['NEXT_MONTH_DEFAULT']
X=df.drop('NEXT_MONTH_DEFAULT',axis=1)

# %% [markdown]
# ## Sampling
#
# ### this dataset is inbalanced. its affecting to the recall and precision ( also f1score )
# ### over sampling is a better solution for that
# ### we use imblearn library to over sampling our data
#
# ### we know sampling affected to model accuracy. but accuracy is not only the key performance of the model. we should keep better f1score.

# %% [markdown]
# ### before sampling

# %%
import seaborn as sns
sns.set(style="darkgrid")
ax = sns.countplot(x="NEXT_MONTH_DEFAULT", data=Y.to_frame())

# %%
from imblearn.over_sampling import SMOTE, ADASYN
X_resampled, y_resampled = SMOTE().fit_resample(X, Y)

# %% [markdown]
# ### after sampling

# %%
ax = sns.countplot(x="NEXT_MONTH_DEFAULT", data=y_resampled.to_frame())

# %% [markdown]
# ###  split the training data to train set and test set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_resampled,y_resampled, test_size = 0.2,random_state=42)

# %% [markdown]
# ### we use RandomForestClassifier for our model. it is good for binary classfication

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(n_estimators=500,max_features='auto',random_state=0,
                          max_depth=10)
clf.fit(x_train,y_train)

y_pred=clf.predict(x_test)
y_train_pred = clf.predict(x_train)

# %% [markdown]
# ### XGBoost model

# %%
from xgboost import XGBClassifier
clf=XGBClassifier(silent=False, 
                      scale_pos_weight=1,
                      learning_rate=0.01,  
                      colsample_bytree = 0.4,
                      subsample = 0.8,
                      objective='binary:logistic', 
                      n_estimators=400, 
                      reg_alpha = 0.3,
                      max_depth=12, 
                      gamma=10)
clf.fit(x_train,y_train)

y_pred=clf.predict(x_test)
y_train_pred = clf.predict(x_train)

# %%
# from sklearn.ensemble import RandomForestClassifier
# clf_test=XGBClassifier(silent=False, 
#                       scale_pos_weight=1,
#                       learning_rate=0.01,  
#                       colsample_bytree = 0.4,
#                       subsample = 0.8,
#                       objective='binary:logistic', 
#                       n_estimators=400, 
#                       reg_alpha = 0.3,
#                       max_depth=12, 
#                       gamma=10)
# clf_test.fit(X_resampled,y_resampled)

# y_pred_test=clf_test.predict(test)

# %%
# di_ct={'Client_ID':test1.Client_ID,'NEXT_MONTH_DEFAULT':y_pred_test}

# testdf=pd.DataFrame(di_ct)
# testdf.to_csv('file5.csv', header=True, index=False)

# %% [markdown]
# ### Accuracies

# %%
from sklearn import metrics

print("train accuracy= ",metrics.accuracy_score(y_train, y_train_pred))
print("test accuracy= ", metrics.accuracy_score(y_test, y_pred))
# Out:
# train accuracy=  0.856621585431173
# test accuracy=  0.8462774504552758

# %% [markdown]
# ### confusion matrix

# %%
from sklearn.metrics import classification_report

target_names = ['0','1']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85      3820
#            1       0.86      0.82      0.84      3648
#
#     accuracy                           0.85      7468
#    macro avg       0.85      0.85      0.85      7468
# weighted avg       0.85      0.85      0.85      7468

# %% [markdown]
# ### Cross validation

# %%
from sklearn.model_selection import cross_val_score
all_accuracies = cross_val_score(estimator=clf, X=x_train, y=y_train, cv=10)

print(all_accuracies)
# Out:
# [0.83467202 0.83701473 0.83997322 0.83327754 0.84131235 0.83796451
#  0.8382993  0.84231671 0.82926013 0.84566455]

# %%
print(all_accuracies.mean())
# Out:
# 0.8379755042937065

# %% [markdown]
# ## Tunning the model
# ### we use GridSearchCV library for that

# %%
grid_param = {
    'n_estimators': [300,500,700,900],
    'criterion': ['gini','entropy'],
    'bootstrap': [True, False],
    'max_depth':[10,12,13]
}

# %%
from sklearn.model_selection import GridSearchCV
gd_sr1 = GridSearchCV(estimator=clf,
                     param_grid=grid_param,
                     scoring='accuracy',
                     cv=5,
                     n_jobs=-1)

# %%
# gd_sr1.fit(x_train, y_train)

# %% [markdown]
# ## Feature importance

# %%
X.columns
# Out:
# Index(['Balance_Limit_V1', 'Gender', 'EDUCATION_STATUS', 'MARITAL_STATUS',
#        'AGE', 'PAY_JULY', 'PAY_AUG', 'PAY_SEP', 'PAY_OCT', 'PAY_NOV',
#        'PAY_DEC', 'DUE_AMT_JULY', 'DUE_AMT_AUG', 'DUE_AMT_SEP', 'DUE_AMT_OCT',
#        'DUE_AMT_NOV', 'DUE_AMT_DEC', 'PAID_AMT_JULY', 'PAID_AMT_AUG',
#        'PAID_AMT_SEP', 'PAID_AMT_OCT', 'PAID_AMT_NOV', 'PAID_AMT_DEC',
#        'DUE_AMT', 'PAY'],
#       dtype='object')

# %%
a=['Balance_Limit_V1', 'Gender', 'EDUCATION_STATUS', 'MARITAL_STATUS',
       'AGE', 'PAY_JULY', 'PAY_AUG', 'PAY_SEP', 'PAY_OCT', 'PAY_NOV',
       'PAY_DEC', 'DUE_AMT_JULY', 'DUE_AMT_AUG', 'DUE_AMT_SEP', 'DUE_AMT_OCT',
       'DUE_AMT_NOV', 'DUE_AMT_DEC', 'PAID_AMT_JULY', 'PAID_AMT_AUG',
       'PAID_AMT_SEP', 'PAID_AMT_OCT', 'PAID_AMT_NOV', 'PAID_AMT_DEC',
       'DUE_AMT', 'PAY']
feature_imp = pd.Series(clf.feature_importances_,index=a).sort_values(ascending=False)
feature_imp
# Out:
# PAY_JULY            0.110577
# Gender              0.108382
# PAY_AUG             0.102000
# PAY                 0.073810
# MARITAL_STATUS      0.061034
# PAY_SEP             0.058828
# AGE                 0.056412
# PAY_OCT             0.039348
# EDUCATION_STATUS    0.038335
# PAY_NOV             0.037646
# PAY_DEC             0.028510
# PAID_AMT_JULY       0.026524
# Balance_Limit_V1    0.024869
# PAID_AMT_AUG        0.024703
# DUE_AMT_JULY        0.024206
# DUE_AMT             0.022617
# DUE_AMT_SEP         0.021811
# PAID_AMT_OCT        0.020770
# DUE_AMT_AUG         0.020735
# PAID_AMT_SEP        0.019688
# PAID_AMT_NOV        0.016678
# DUE_AMT_OCT         0.016517
# PAID_AMT_DEC        0.016387
# DUE_AMT_NOV         0.016226
# DUE_AMT_DEC         0.013388
# dtype: float32

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
